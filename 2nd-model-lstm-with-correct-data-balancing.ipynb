# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cremad/AudioWAV/1028_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1084_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1023_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1076_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1055_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1035_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1081_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1031_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1024_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1028_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1089_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1080_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1073_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1021_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1081_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1071_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1011_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1058_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1021_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1057_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1071_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1044_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1010_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1045_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1057_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1017_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1070_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1011_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1029_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1040_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1057_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1071_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1018_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1050_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1090_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1049_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1007_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1046_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1069_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1024_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1053_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1002_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1068_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1005_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1049_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1009_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1007_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1033_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1023_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1008_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1047_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1009_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1024_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1038_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1079_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1059_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1010_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1028_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1061_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1037_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1023_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1020_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1020_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1026_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1079_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1036_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1059_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1065_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1086_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1081_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1078_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1081_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1016_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_IWW_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1027_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1040_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1063_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1072_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1063_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1075_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1080_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1004_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1027_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1050_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1079_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1018_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1055_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1065_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1010_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1010_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1078_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1081_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1064_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1056_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1059_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1007_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1089_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1031_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1076_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1047_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1086_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1031_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1071_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1013_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1023_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1016_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1032_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1025_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1088_IWW_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1032_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1086_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1028_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1063_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1077_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1017_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1015_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1016_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1074_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1057_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1071_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1057_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1008_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1041_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1069_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1086_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1056_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1017_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1071_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1014_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1031_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1012_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1081_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1046_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1033_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1046_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1019_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1082_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1045_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1085_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1058_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1036_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1016_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1071_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1025_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1088_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1081_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1007_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1020_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1054_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1010_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1024_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1023_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1090_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1080_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1022_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1090_IWW_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1039_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1039_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1009_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1032_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1010_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1023_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1026_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1089_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1033_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1071_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1004_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1023_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1031_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1024_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1023_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1039_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1027_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1089_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1061_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1037_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1023_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1030_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1086_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1083_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1091_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1023_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1077_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1030_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1052_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1069_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1031_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1046_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1071_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1063_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1059_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1008_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1039_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1086_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1038_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1081_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1056_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1001_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1088_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1044_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1046_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1049_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1090_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1041_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1030_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1077_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1068_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1071_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1054_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1052_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1017_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1045_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1058_IWW_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_WSI_FEA_XX.wav
# ...
# /kaggle/input/cremad/AudioWAV/1054_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1022_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1023_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1081_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1091_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1034_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1020_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1070_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1076_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IOM_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1018_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1083_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1068_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1044_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1067_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1063_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1073_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1055_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1069_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1066_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1027_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1060_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1056_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1035_DFA_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1061_IEO_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1081_ITS_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1074_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1047_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1051_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1028_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1033_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1014_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1029_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1088_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1047_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1051_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1048_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1012_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1047_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1005_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1067_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1015_IWW_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_TAI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1066_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1065_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1077_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1019_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1088_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1001_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1071_MTI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_ITS_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1073_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_WSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1030_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1002_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_IEO_FEA_LO.wav
# /kaggle/input/cremad/AudioWAV/1024_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1059_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1030_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1049_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1049_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1079_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1072_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1071_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_TSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_ITS_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1007_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1039_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_ITH_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1005_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1024_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1024_IOM_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1031_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1021_IWL_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_MTI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1057_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_TAI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1087_IOM_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_TIE_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1026_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1077_TAI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1067_IWW_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1017_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1045_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1010_TSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1046_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_TSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1032_TSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1006_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1007_DFA_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1080_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1048_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1013_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_IWW_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1090_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1030_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_WSI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_IEO_FEA_MD.wav
# /kaggle/input/cremad/AudioWAV/1081_IEO_HAP_MD.wav
# /kaggle/input/cremad/AudioWAV/1008_MTI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_DFA_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1064_IOM_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1042_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1078_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1089_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1042_IEO_ANG_HI.wav
# /kaggle/input/cremad/AudioWAV/1039_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1013_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1038_IEO_SAD_LO.wav
# /kaggle/input/cremad/AudioWAV/1006_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_ITS_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1018_TSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1040_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1084_MTI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1046_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1085_TIE_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1036_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1086_IEO_DIS_LO.wav
# /kaggle/input/cremad/AudioWAV/1049_IEO_SAD_MD.wav
# /kaggle/input/cremad/AudioWAV/1052_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1085_MTI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1029_ITS_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1038_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1053_TIE_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1065_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_MTI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1075_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IEO_SAD_HI.wav
# /kaggle/input/cremad/AudioWAV/1045_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_TAI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_WSI_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1025_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IOM_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_TIE_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1016_ITH_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IWL_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1061_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1021_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_IWL_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1028_IEO_ANG_LO.wav
# /kaggle/input/cremad/AudioWAV/1053_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1003_TSI_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_TAI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1048_ITH_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1058_IWL_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1083_IWW_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1022_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1087_IWW_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1037_DFA_DIS_XX.wav
# /kaggle/input/cremad/AudioWAV/1020_IWW_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_IWW_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1012_TAI_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_IEO_FEA_HI.wav
# /kaggle/input/cremad/AudioWAV/1031_IEO_HAP_HI.wav
# /kaggle/input/cremad/AudioWAV/1022_DFA_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1082_ITS_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IEO_HAP_LO.wav
# /kaggle/input/cremad/AudioWAV/1079_IEO_DIS_MD.wav
# /kaggle/input/cremad/AudioWAV/1044_IEO_DIS_HI.wav
# /kaggle/input/cremad/AudioWAV/1041_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1019_DFA_NEU_XX.wav
# /kaggle/input/cremad/AudioWAV/1091_TIE_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1014_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1062_ITH_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1041_ITH_FEA_XX.wav
# /kaggle/input/cremad/AudioWAV/1079_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1043_ITH_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1011_TIE_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1059_WSI_HAP_XX.wav
# /kaggle/input/cremad/AudioWAV/1033_WSI_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_WSI_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1008_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1060_IEO_ANG_MD.wav
# /kaggle/input/cremad/AudioWAV/1088_IWL_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1050_IOM_ANG_XX.wav
# /kaggle/input/cremad/AudioWAV/1044_IWL_SAD_XX.wav
# /kaggle/input/cremad/AudioWAV/1009_ITH_SAD_XX.wav

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ejlok1/cremad")

print("Path to dataset files:", path)

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
from sklearn.utils import resample
from pathlib import Path

# %%
pip install librosa matplotlib pandas

# %%
crema_path = '/kaggle/input/cremad/AudioWAV'
output_root = Path('./CREMA_augmented_outputs')
logmel_npy_dir = output_root / 'logmel_arrays_noised'
logmel_plot_dir = output_root / 'logmel_spectrograms_noised'
hist_dir = output_root / 'histograms'

# %%
FIXED_LENGTH_SEC = 3
WINDOW_SIZE = 0.025  
HOP_SIZE = 0.010

# %%
for folder in [logmel_npy_dir, logmel_plot_dir, hist_dir]:
    folder.mkdir(parents=True, exist_ok=True)


def extract_emotion(filename):
    parts = filename.split('_')
    return parts[2] if len(parts) >= 4 else None

files = [f for f in os.listdir(crema_path) if f.endswith('.wav')]
data = pd.DataFrame({
    'filename': files,
    'emotion': [extract_emotion(f) for f in files]
})
data = data[data['emotion'].notna()].reset_index(drop=True)

print(f" Total audio files: {len(files)}")
print(f" Files with valid emotion labels: {len(data)}")
print(f" Emotion classes: {sorted(data['emotion'].unique())}")
# Out:
#  Total audio files: 7442
#  Files with valid emotion labels: 7442
#  Emotion classes: ['ANG', 'DIS', 'FEA', 'HAP', 'NEU', 'SAD']

# %%
emotion_plot_counter = {}
file_instance_counter = {}
failed_files = []

# %%
def save_logmel_with_deltas_unique(filename, emotion):
    filepath = os.path.join(crema_path, filename)
    y, sr = librosa.load(filepath, sr=None)

    # Inject noise
    noise_amp = 0.035 * np.random.uniform() * np.amax(y)
    y += noise_amp * np.random.normal(size=y.shape[0])

    y = (y - np.mean(y)) / (np.std(y) + 1e-9)

    target_len = sr * FIXED_LENGTH_SEC
    y = y[:target_len] if len(y) > target_len else np.pad(y, (0, target_len - len(y)))

    n_fft = int(sr * WINDOW_SIZE)
    hop_length = int(sr * HOP_SIZE)
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=64)
    logmel = librosa.power_to_db(mel, ref=np.max)
    delta = librosa.feature.delta(logmel)
    delta2 = librosa.feature.delta(logmel, order=2)
    combined = np.stack([logmel, delta, delta2], axis=0)  # shape: (3, 64, T)

    base_name = filename.replace('.wav', '')
    count = file_instance_counter.get(base_name, 0)
    file_instance_counter[base_name] = count + 1
    unique_name = f"{base_name}_{count}"

    # Save .npy file
    np.save(logmel_npy_dir / f"{unique_name}.npy", combined)

    if emotion_plot_counter.get(emotion, 0) < 3:
        plt.figure(figsize=(10, 3))
        librosa.display.specshow(logmel, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel')
        plt.title(f'Log-Mel Spectrogram: {emotion}')
        plt.axis('off')
        plt.tight_layout()
        plt.savefig(logmel_plot_dir / f"{unique_name}.png")
        plt.close()
        emotion_plot_counter[emotion] = emotion_plot_counter.get(emotion, 0) + 1

# %%
for _, row in data.iterrows():
    try:
        save_logmel_with_deltas_unique(row['filename'], row['emotion'])
    except Exception as e:
        print(f"Failed: {row['filename']} | Reason: {e}")
        failed_files.append(row['filename'])

all_outputs = list(logmel_npy_dir.glob("*.npy"))
print("\n Processing Complete")
print(f"Files saved (including duplicates): {len(all_outputs)}")
print(f"Files failed: {len(failed_files)}")
# Out:
#  Processing Complete
# Files saved (including duplicates): 7442
# Files failed: 0

# %%
X, y = [], []

for f in os.listdir(logmel_npy_dir):
    if f.endswith(".npy"):
        array = np.load(os.path.join(logmel_npy_dir, f))
        if array.shape[2] < 300:
            pad = 300 - array.shape[2]
            array = np.pad(array, ((0, 0), (0, 0), (0, pad)))
        elif array.shape[2] > 300:
            array = array[:, :, :300]
        X.append(np.transpose(array, (2, 1, 0)))  # (time, mel, channels)
        y.append(extract_emotion(f))

# %%
X = np.array(X)
y = np.array(y)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y)
num_classes = len(le.classes_)
# Out:
# 2025-04-27 11:33:33.006084: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745753613.260946      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745753613.342747      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

# %%
def plot_distribution(labels, title, filename):
    label_names = le.inverse_transform(np.unique(labels))
    counts = pd.Series(labels).value_counts().sort_index()
    counts.index = label_names

    plt.figure(figsize=(8, 5))
    counts.plot(kind='bar')
    plt.title(title)
    plt.xlabel("Emotion")
    plt.ylabel("Number of Audio Files")
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Save the figure
    plt.savefig(hist_dir / filename)
    plt.show()
    plt.close()

plot_distribution(y_train_final, "Train Set Before Oversampling", "train_before_oversampling.png")

# %%
train_df = pd.DataFrame({'idx': np.arange(len(y_train_final)), 'label': y_train_final})
max_count = train_df['label'].value_counts().max()

balanced_indices = pd.concat([
    resample(group, replace=True, n_samples=max_count, random_state=42)
    for _, group in train_df.groupby('label')
])['idx'].values

X_train_balanced = X_train_final[balanced_indices]
y_train_balanced = y_train_final[balanced_indices]

# %%
y_train_cat = tf.keras.utils.to_categorical(y_train_balanced, num_classes=num_classes)
y_val_cat = tf.keras.utils.to_categorical(y_val, num_classes=num_classes)
y_test_cat = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

# %%
plot_distribution(y_train_balanced, "Train Set After Oversampling", "train_after_oversampling.png")
print("X_train_balanced:", X_train_balanced.shape)
print("y_train_cat:", y_train_cat.shape)
print("X_val:", X_val.shape)
print("y_val_cat:", y_val_cat.shape)
print("X_test:", X_test.shape)
print("y_test_cat:", y_test_cat.shape)
# Out:
# X_train_balanced: (4884, 300, 64, 3)
# y_train_cat: (4884, 6)
# X_val: (1191, 300, 64, 3)
# y_val_cat: (1191, 6)
# X_test: (1489, 300, 64, 3)
# y_test_cat: (1489, 6)

# %%
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization, Dropout

def create_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(128, (5, 3), padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(pool_size=(1, 2))(x)
   
    x = layers.Conv2D(256, (5, 3), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(pool_size=(1, 2))(x)

    x = layers.Reshape((-1, x.shape[-2] * x.shape[-1]))(x)  # (batch, time, features)
    x = layers.LSTM(128, return_sequences=True)(x)
    x = layers.Dropout(0.3)(x)
    
    attention_output = MultiHeadAttention(num_heads=2, key_dim=128)(x, x)
    context = layers.GlobalAveragePooling1D()(attention_output)
    
    x = layers.Dense(64, activation='relu')(context)
    x = Dropout(0.3)(x) 
   
    outputs = layers.Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    return tf.keras.Model(inputs, outputs)

# %%
model = create_model(X_train[0].shape, num_classes)
model.summary()
# Out:
# I0000 00:00:1745753644.720556      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1745753644.721223      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 300, 64, 3)     │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 300, 64, 128)   │          5,888 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 300, 64, 128)   │            512 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 300, 32, 128)   │              0 │ batch_normalization[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 300, 32, 256)   │        491,776 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 300, 32, 256)   │          1,024 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 300, 16, 256)   │              0 │ batch_normalization_1… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 300, 4096)      │              0 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm (LSTM)               │ (None, 300, 128)       │      2,163,200 │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 300, 128)       │              0 │ lstm[0][0]             │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 300, 128)       │        131,968 │ dropout[0][0],         │
# │ (MultiHeadAttention)      │                        │                │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 128)            │              0 │ multi_head_attention[… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │          8,256 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64)             │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 6)              │            390 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,803,014 (10.69 MB)
#  Trainable params: 2,802,246 (10.69 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# Learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=1000,
    decay_rate=0.95,
    staircase=True
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=output_root / "saved_models/best_model.keras",
        save_best_only=True
    ),
    
    tf.keras.callbacks.TensorBoard(
        log_dir=output_root / "tensorboard_logs",
        histogram_freq=1
    )
]

# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipvalue=5.0)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train_balanced, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# I0000 00:00:1745753765.197352     113 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 76s 410ms/step - accuracy: 0.2845 - loss: 1.6582 - val_accuracy: 0.3736 - val_loss: 1.5092
# Epoch 2/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 410ms/step - accuracy: 0.3951 - loss: 1.4887 - val_accuracy: 0.4131 - val_loss: 1.4443
# Epoch 3/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.4365 - loss: 1.4265 - val_accuracy: 0.3871 - val_loss: 1.4819
# Epoch 4/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.4650 - loss: 1.3383 - val_accuracy: 0.3627 - val_loss: 1.5824
# Epoch 5/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.5058 - loss: 1.2776 - val_accuracy: 0.4383 - val_loss: 1.3663
# Epoch 6/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.5542 - loss: 1.1716 - val_accuracy: 0.4307 - val_loss: 1.3561
# Epoch 7/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.6100 - loss: 1.0498 - val_accuracy: 0.4391 - val_loss: 1.3862
# Epoch 8/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.6661 - loss: 0.9288 - val_accuracy: 0.5416 - val_loss: 1.1887
# Epoch 9/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.6971 - loss: 0.8429 - val_accuracy: 0.5525 - val_loss: 1.1654
# Epoch 10/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.7549 - loss: 0.6787 - val_accuracy: 0.5088 - val_loss: 1.4056
# Epoch 11/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.8028 - loss: 0.5650 - val_accuracy: 0.4996 - val_loss: 1.4229
# Epoch 12/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.8251 - loss: 0.4899 - val_accuracy: 0.5525 - val_loss: 1.2942
# Epoch 13/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.8854 - loss: 0.3466 - val_accuracy: 0.5105 - val_loss: 1.5889
# Epoch 14/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.9000 - loss: 0.3063 - val_accuracy: 0.5424 - val_loss: 1.5413
# Epoch 15/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 415ms/step - accuracy: 0.9345 - loss: 0.2108 - val_accuracy: 0.5533 - val_loss: 1.5193
# Epoch 16/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9456 - loss: 0.1744 - val_accuracy: 0.5575 - val_loss: 1.6615
# Epoch 17/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 64s 416ms/step - accuracy: 0.9680 - loss: 0.1091 - val_accuracy: 0.4887 - val_loss: 2.0624
# Epoch 18/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9687 - loss: 0.1095 - val_accuracy: 0.5416 - val_loss: 1.7807
# Epoch 19/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 415ms/step - accuracy: 0.9821 - loss: 0.0716 - val_accuracy: 0.5424 - val_loss: 2.0793
# Epoch 20/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9734 - loss: 0.0900 - val_accuracy: 0.5340 - val_loss: 2.1002
# Epoch 21/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9764 - loss: 0.0806 - val_accuracy: 0.5584 - val_loss: 2.0204
# Epoch 22/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9844 - loss: 0.0519 - val_accuracy: 0.5516 - val_loss: 2.0268
# Epoch 23/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9835 - loss: 0.0516 - val_accuracy: 0.5382 - val_loss: 1.9745
# Epoch 24/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.9759 - loss: 0.0734 - val_accuracy: 0.4996 - val_loss: 2.4808
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

y_val_pred_probs = model.predict(X_val)
y_val_pred_labels = np.argmax(y_val_pred_probs, axis=1)

y_val_true_labels = y_val

emotion_names = le.classes_

print("\Classification Report:\n")
print(classification_report(y_val_true_labels, y_val_pred_labels, target_names=emotion_names))

cm_val = confusion_matrix(y_val_true_labels, y_val_pred_labels)
disp_val = ConfusionMatrixDisplay(confusion_matrix=cm_val, display_labels=emotion_names)
disp_val.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step
# \Classification Report:
#
#               precision    recall  f1-score   support
#
#          ANG       0.72      0.70      0.71       204
#          DIS       0.48      0.52      0.50       203
#          FEA       0.62      0.37      0.46       204
#          HAP       0.51      0.50      0.51       203
#          NEU       0.48      0.68      0.56       174
#          SAD       0.56      0.56      0.56       203
#
#     accuracy                           0.55      1191
#    macro avg       0.56      0.56      0.55      1191
# weighted avg       0.56      0.55      0.55      1191

# %%
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=1)

print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.5588 - loss: 1.1761
# Test Accuracy: 55.20%

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Predict on test set
y_test_pred_probs = model.predict(X_test)
y_test_pred_labels = np.argmax(y_test_pred_probs, axis=1)
y_test_true_labels = y_test

# Inverse transform to get original labels
class_names = le.classes_

# Class-wise accuracy
print("\nPer-Class Test Accuracy:\n")
for class_idx, class_name in enumerate(class_names):
    idxs = np.where(y_test_true_labels == class_idx)[0]
    correct = np.sum(y_test_pred_labels[idxs] == class_idx)
    total = len(idxs)
    acc = correct / total if total > 0 else 0.0
    print(f"{class_name}: {acc:.4f} ({correct}/{total})")
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step
#
# Per-Class Test Accuracy:
#
# ANG: 0.6024 (153/254)
# DIS: 0.5787 (147/254)
# FEA: 0.3150 (80/254)
# HAP: 0.5255 (134/255)
# NEU: 0.7064 (154/218)
# SAD: 0.6063 (154/254)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history, save_path=None):
    """
    Plots training and validation accuracy and loss curves.

    Parameters:
    - history: Keras History object
    - save_path: Optional path to save the figure
    """
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r--', label='Validation Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b-', label='Training Loss')
    plt.plot(epochs, val_loss, 'r--', label='Validation Loss')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path)
    plt.show()

# Usage
plot_training_history(history, save_path=output_root/"accuracy_loss_plot")

# %%
import shutil
shutil.make_archive("/kaggle/working/CREMA_augmented_outputs", 'zip', "/kaggle/working")
# Out:
# '/kaggle/working/CREMA_augmented_outputs.zip'
